# %%
from functions import *

# 查看路径和配置
print(f"数据目录: {DATA_DIR}")
print(f"Excel文件: {DAYU_EXCEL}")
print(f"默认CRS: {DEFAULT_CRS}")
# Out:
# 数据目录: c:\Phd_art\tianyu_research\glb_equal\data
# Excel文件: c:\Phd_art\tianyu_research\glb_equal\data\dayu.xlsx
# 默认CRS: EPSG:4326
